# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = '~/data/distonx.csv'
data = pd.read_csv(PATH)

# %%
data
# Out:
#             id          time currency_pair  kline_trade_number  \
# 0            1  1.581428e+09       bnbusdt                  90
# 1            2  1.581428e+09        ltcbtc                  37
# 2            3  1.581428e+09        ethbtc                 209
# 3            4  1.581428e+09       btcusdt                 637
# 4            5  1.581428e+09       ethusdt                 211
# ...        ...           ...           ...                 ...
# 107200  107201  1.581440e+09       ltcusdt                  43
# 107201  107202  1.581440e+09        ltcbnb                   0
# 107202  107203  1.581440e+09        bchbtc                  20
# 107203  107204  1.581440e+09       bchusdt                  52
# 107204  107205  1.581440e+09        bnbbtc                 199
#
#         kline_open_price  kline_close_price  kline_high_price  \
# 0              25.090500          25.072600         25.090500
# 1               0.007513           0.007514          0.007517
# 2               0.022668           0.022672          0.022684
# 3            9899.420000        9903.110000       9904.760000
# 4             224.410000         224.520000        224.550000
# ...                  ...                ...               ...
# 107200         76.200000          76.070000         76.220000
# 107201          3.052000           3.052000          3.052000
# 107202          0.045196           0.045179          0.045202
# 107203        462.000000         461.390000        462.000000
# 107204          0.002446           0.002444          0.002447
#
#         kline_low_price  kline_base_volume  kline_quote_volume  ...  \
# 0             25.059400        1168.770000        29310.907722  ...
# 1              0.007513          76.600000            0.575639  ...
# 2              0.022665         802.450000           18.192120  ...
# 3           9895.080000          53.008219       524722.027914  ...
# 4            224.380000         684.376270       153590.034043  ...
# ...                 ...                ...                 ...  ...
# 107200        76.070000         389.625050        29656.310408  ...
# 107201         3.052000           0.000000            0.000000  ...
# 107202         0.045172          16.339000            0.738195  ...
# 107203       461.320000          78.125170        36063.310270  ...
# 107204         0.002442        1223.070000            2.990455  ...
#
#         depth_ask_quantity_11  depth_ask_quantity_12  depth_ask_quantity_13  \
# 0                   153.73000              13.700000               5.850000
# 1                   181.73000             293.310000               0.260000
# 2                    22.89600               1.400000               1.455000
# 3                     0.60000               0.020191               0.131554
# 4                    27.70203              17.012800              10.499550
# ...                       ...                    ...                    ...
# 107200               71.16412             159.825080             215.282360
# 107201                0.36700               0.077000               0.277000
# 107202                0.37500               3.229000               1.124000
# 107203               17.17440               0.375030              12.094110
# 107204                2.93000               2.170000               3.090000
#
#         depth_ask_quantity_14  depth_ask_quantity_15  depth_ask_quantity_16  \
# 0                     6.92000              555.75000              24.130000
# 1                   173.24000                4.95000              40.640000
# 2                     3.62500                5.82800               1.426000
# 3                     1.20000                0.20000               0.036433
# 4                    11.01988              157.30799              98.785130
# ...                       ...                    ...                    ...
# 107200              295.79927               22.16181              46.981810
# 107201                0.28900              144.84500               0.356000
# 107202                2.21300                3.28300               9.340000
# 107203                1.40553                2.75000               3.069540
# 107204                4.71000                1.69000               2.970000
#
#         depth_ask_quantity_17  depth_ask_quantity_18  depth_ask_quantity_19  \
# 0                  102.650000               6.920000             119.630000
# 1                   62.730000              20.120000              33.220000
# 2                    1.710000               1.400000             114.480000
# 3                    0.005157               0.929697               0.017545
# 4                   12.290570              38.555050               6.381370
# ...                       ...                    ...                    ...
# 107200              19.283920              86.055170              61.917800
# 107201               0.236000               0.107000               7.387000
# 107202              23.530000               2.254000               0.376000
# 107203               0.648930               2.212840               3.534020
# 107204             100.000000               2.890000               2.870000
#
#         depth_ask_quantity_20
# 0                   13.840000
# 1                   43.880000
# 2                   97.466000
# 3                    0.619148
# 4                    8.556130
# ...                       ...
# 107200               4.963020
# 107201               2.292000
# 107202               0.751000
# 107203               0.775550
# 107204               0.150000
#
# [107205 rows x 94 columns]

# %%
data['target'] = (data['depth_bid_price_1'] + data['depth_ask_price_1']) / 2

# %%
data.loc[range(0, 200, 11)]
# Out:
#       id          time currency_pair  kline_trade_number  kline_open_price  \
# 0      1  1.581428e+09       bnbusdt                  90           25.0905
# 11    12  1.581428e+09       bnbusdt                  90           25.0905
# 22    23  1.581428e+09       bnbusdt                  90           25.0905
# 33    34  1.581428e+09       bnbusdt                  90           25.0905
# 44    45  1.581428e+09       bnbusdt                  90           25.0905
# 55    56  1.581428e+09       bnbusdt                  90           25.0905
# 66    67  1.581428e+09       bnbusdt                  90           25.0905
# 77    78  1.581428e+09       bnbusdt                  90           25.0905
# 88    89  1.581428e+09       bnbusdt                  90           25.0905
# 99   100  1.581428e+09       bnbusdt                  90           25.0905
# 110  111  1.581428e+09       bnbusdt                  90           25.0905
# 121  122  1.581428e+09       bnbusdt                  90           25.0905
# 132  133  1.581428e+09       bnbusdt                  90           25.0905
# 143  144  1.581428e+09       bnbusdt                  90           25.0905
# 154  155  1.581428e+09       bnbusdt                  90           25.0905
# 165  166  1.581428e+09       bnbusdt                  90           25.0905
# 176  177  1.581428e+09       bnbusdt                  90           25.0905
# 187  188  1.581428e+09       bnbusdt                  90           25.0905
# 198  199  1.581428e+09       bnbusdt                  90           25.0905
#
#      kline_close_price  kline_high_price  kline_low_price  kline_base_volume  \
# 0              25.0726           25.0905          25.0594            1168.77
# 11             25.0726           25.0905          25.0594            1168.77
# 22             25.0726           25.0905          25.0594            1168.77
# 33             25.0726           25.0905          25.0594            1168.77
# 44             25.0726           25.0905          25.0594            1168.77
# 55             25.0726           25.0905          25.0594            1168.77
# 66             25.0726           25.0905          25.0594            1168.77
# 77             25.0726           25.0905          25.0594            1168.77
# 88             25.0726           25.0905          25.0594            1168.77
# 99             25.0726           25.0905          25.0594            1168.77
# 110            25.0726           25.0905          25.0594            1168.77
# 121            25.0726           25.0905          25.0594            1168.77
# 132            25.0726           25.0905          25.0594            1168.77
# 143            25.0726           25.0905          25.0594            1168.77
# 154            25.0726           25.0905          25.0594            1168.77
# 165            25.0726           25.0905          25.0594            1168.77
# 176            25.0726           25.0905          25.0594            1168.77
# 187            25.0726           25.0905          25.0594            1168.77
# 198            25.0726           25.0905          25.0594            1168.77
#
#      kline_quote_volume  ...  depth_ask_quantity_12  depth_ask_quantity_13  \
# 0          29310.907722  ...                  13.70                   5.85
# 11         29310.907722  ...                   6.92                 555.75
# 22         29310.907722  ...                  19.94                   5.85
# 33         29310.907722  ...                  13.70                  19.94
# 44         29310.907722  ...                  13.70                  19.94
# 55         29310.907722  ...                  13.70                  19.94
# 66         29310.907722  ...                  19.94                   5.85
# 77         29310.907722  ...                  77.04                  56.42
# 88         29310.907722  ...                 100.00                   2.99
# 99         29310.907722  ...                   2.99                  77.04
# 110        29310.907722  ...                 151.09                   6.81
# 121        29310.907722  ...                   6.81                  77.04
# 132        29310.907722  ...                   6.81                  77.04
# 143        29310.907722  ...                   6.81                  77.04
# 154        29310.907722  ...                  13.70                   5.85
# 165        29310.907722  ...                  77.04                   2.64
# 176        29310.907722  ...                  77.04                   2.64
# 187        29310.907722  ...                   2.99                   2.64
# 198        29310.907722  ...                  76.81                   2.99
#
#      depth_ask_quantity_14  depth_ask_quantity_15  depth_ask_quantity_16  \
# 0                     6.92                 555.75                  24.13
# 11                   24.13                 102.65                   6.92
# 22                    6.92                 555.75                  24.13
# 33                    5.85                   6.92                 555.75
# 44                    5.85                   6.92                 555.75
# 55                    5.85                   6.92                 555.75
# 66                    6.92                 555.75                  24.13
# 77                    2.64                  13.70                  19.94
# 88                   77.04                   2.64                  13.70
# 99                    2.64                  13.70                  19.94
# 110                  77.04                   2.64                  13.70
# 121                   2.64                  13.70                   5.85
# 132                   2.64                  13.70                   5.85
# 143                   2.64                  13.70                   5.85
# 154                   6.92                 555.75                  24.13
# 165                  13.70                   5.85                   6.92
# 176                  13.70                   5.85                   6.92
# 187                  13.70                   5.85                   6.92
# 198                  17.45                   2.64                  39.49
#
#      depth_ask_quantity_17  depth_ask_quantity_18  depth_ask_quantity_19  \
# 0                   102.65                   6.92                 119.63
# 11                  119.63                  13.84                   2.53
# 22                  102.65                   6.92                 119.63
# 33                   24.13                 102.65                   6.92
# 44                   24.13                 102.65                   6.92
# 55                   24.13                 102.65                   6.92
# 66                  102.65                   6.92                 119.63
# 77                    5.85                   6.92                 555.75
# 88                   19.94                   5.85                   6.92
# 99                    5.85                   6.92                 555.75
# 110                   5.85                   6.92                 555.75
# 121                   6.92                 555.75                  24.13
# 132                   6.92                 555.75                  24.13
# 143                   6.92                 555.75                  24.13
# 154                 119.65                 102.65                   6.92
# 165                 555.75                  24.13                 119.65
# 176                 555.75                  24.13                 718.00
# 187                 555.75                  24.13                 718.00
# 198                  13.70                   5.85                   6.92
#
#      depth_ask_quantity_20    target
# 0                    13.84  25.07750
# 11                   79.01  25.07750
# 22                   13.84  25.08010
# 33                  119.63  25.07930
# 44                  119.63  25.07925
# 55                  119.63  25.07905
# 66                   13.84  25.07905
# 77                   24.13  25.07625
# 88                  555.75  25.07625
# 99                   24.13  25.07625
# 110                  24.13  25.07625
# 121                 119.65  25.07625
# 132                 119.65  25.07625
# 143                 119.65  25.07695
# 154                  13.84  25.07695
# 165                 102.65  25.07695
# 176                 119.65  25.07660
# 187                 102.65  25.06810
# 198                 555.75  25.07375
#
# [19 rows x 95 columns]

# %%
data['target'].shift(-110).loc[range(0, 100, 11)]
# Out:
# 0     25.07625
# 11    25.07625
# 22    25.07625
# 33    25.07695
# 44    25.07695
# 55    25.07695
# 66    25.07660
# 77    25.06810
# 88    25.07375
# 99    25.07375
# Name: target, dtype: float64

# %%
data['shift_10_s'] = data['target'].shift(-110)

# %%
data.dropna(inplace=True)

# %%
btcusd = data[data['currency_pair'] == 'btcusdt']

# %%
btcusd['index'] = btcusd.index
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
melt = pd.melt(btcusd, id_vars=['index'], value_vars=['target', 'shift_10_s'])

# %%
melt
# Out:
#         index    variable      value
# 0           3      target   9903.720
# 1          14      target   9905.010
# 2          25      target   9905.010
# 3          36      target   9899.465
# 4          47      target   9899.690
# ...       ...         ...        ...
# 19467  107044  shift_10_s  10220.530
# 19468  107055  shift_10_s  10220.225
# 19469  107066  shift_10_s  10220.175
# 19470  107077  shift_10_s  10220.145
# 19471  107088  shift_10_s  10221.460
#
# [19472 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.lineplot(data=melt[melt['index'] < 1000], x='index', y='value', hue='variable', ax=ax)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge()
model.fit(btcusd.drop(['target', 'shift_10_s', 'currency_pair'], axis=1), btcusd['shift_10_s'])
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.34507e-18): result may not be accurate.
#   overwrite_a=True).T
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
btcusd['prediction'] = model.predict(btcusd.drop(['target', 'shift_10_s', 'currency_pair'], axis=1))
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
melt = pd.melt(btcusd, id_vars=['index'], value_vars=['target', 'shift_10_s', 'prediction'])
fig, ax = plt.subplots(figsize=(15, 10))
sns.lineplot(data=melt[melt['index'] < 1000], x='index', y='value', hue='variable', ax=ax)
