# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
sns.set()

import sys
sys.path.append('..')
from stonks.DataCatcher import DB

# %%
dbase = DB()

# %%
data = dbase.fetch_last(3600 * 24 * 10, 'btcusdt')

# %%
from stonks.auxiliary.data_preprocessing import get_kline_info, get_state, plot_state, plot_target

# %%
plot_target(data)

# %%
y = get_state(data, 0.003)

# %%
plt.figure(figsize=(15, 5))
plot_state(data, y)
plt.show()

plt.figure(figsize=(15, 5))
plot_state(data[:3600], y[:3600])
# Out:
# ../stonks/auxiliary/data_preprocessing.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['normal_time'] = data['time'].apply(datetime.datetime.fromtimestamp)

# %%
klines = get_kline_info(data)
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/ta/trend.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/ta/trend.py:547: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])

# %%
klines.set_index('normal_time', drop=True, inplace=True)

# %%
klines.drop(['time', 'id', 'currency_pair'], axis=1, inplace=True)

# %%
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from stonks.auxiliary.model_selection import fit_predict, get_importances, plot_predictions

# %%
from sklearn.model_selection import cross_val_score

# %%
from importlib import reload
reload(stonks.auxiliary.data_preprocessing)
# Out:
# <module 'stonks.auxiliary.data_preprocessing' from '../stonks/auxiliary/data_preprocessing.py'>

# %%
data.drop()
# Out:
#              id          time currency_pair  kline_trade_number  \
# 0      21315937  1.585680e+09       btcusdt                 363
# 1      21315948  1.585680e+09       btcusdt                 363
# 2      21315959  1.585680e+09       btcusdt                 363
# 3      21315970  1.585680e+09       btcusdt                 363
# 4      21315981  1.585680e+09       btcusdt                 363
# ...         ...           ...           ...                 ...
# 75640  22147974  1.585766e+09       btcusdt                 382
# 75641  22147985  1.585766e+09       btcusdt                 382
# 75642  22147996  1.585766e+09       btcusdt                 382
# 75643  22148007  1.585766e+09       btcusdt                 382
# 75644  22148018  1.585766e+09       btcusdt                 382
#
#        kline_open_price  kline_close_price  kline_high_price  kline_low_price  \
# 0               6476.49            6476.30           6478.00          6472.91
# 1               6476.49            6476.30           6478.00          6472.91
# 2               6476.49            6476.30           6478.00          6472.91
# 3               6476.49            6476.30           6478.00          6472.91
# 4               6476.49            6476.30           6478.00          6472.91
# ...                 ...                ...               ...              ...
# 75640           6206.45            6198.24           6206.84          6197.61
# 75641           6206.45            6198.24           6206.84          6197.61
# 75642           6206.45            6198.24           6206.84          6197.61
# 75643           6206.45            6198.24           6206.84          6197.61
# 75644           6206.45            6198.24           6206.84          6197.61
#
#        kline_base_volume  kline_quote_volume  ...  depth_ask_quantity_12  \
# 0              34.180339       221342.228504  ...               0.005736
# 1              34.180339       221342.228504  ...               0.083143
# 2              34.180339       221342.228504  ...               0.005736
# 3              34.180339       221342.228504  ...               0.088387
# 4              34.180339       221342.228504  ...               0.009487
# ...                  ...                 ...  ...                    ...
# 75640          22.119163       137161.490925  ...               1.033400
# 75641          22.119163       137161.490925  ...               0.200000
# 75642          22.119163       137161.490925  ...               0.200000
# 75643          22.119163       137161.490925  ...               0.232212
# 75644          22.119163       137161.490925  ...               0.200000
#
#        depth_ask_quantity_13  depth_ask_quantity_14  depth_ask_quantity_15  \
# 0                   0.076793               0.075504               0.027949
# 1                   0.027949               0.010000               0.001742
# 2                   0.027949               0.010000               0.001742
# 3                   0.015402               0.193047               0.153763
# 4                   0.015402               0.193047               0.153763
# ...                      ...                    ...                    ...
# 75640               0.020000               5.111623               0.250000
# 75641               0.242063               0.020000               0.100000
# 75642               0.242063               0.173340               0.020000
# 75643               0.200000               0.200000               0.242063
# 75644               0.155867               0.200000               0.242063
#
#        depth_ask_quantity_16  depth_ask_quantity_17  depth_ask_quantity_18  \
# 0                   0.010000               0.001742               0.009487
# 1                   0.009487               0.015402               0.153763
# 2                   0.009487               0.015402               0.193047
# 3                   0.074008               0.100000               0.154380
# 4                   0.100000               0.154380               0.003478
# ...                      ...                    ...                    ...
# 75640               0.161332               1.742859               0.065027
# 75641               0.158000               0.161327               5.111623
# 75642               0.100000               2.197566               0.158000
# 75643               0.173340               0.020000               0.100000
# 75644               0.173340               0.020000               0.100000
#
#        depth_ask_quantity_19  depth_ask_quantity_20                normal_time
# 0                   0.015402               0.153763 2020-03-31 21:41:26.934706
# 1                   0.001702               0.100000 2020-03-31 21:41:28.096272
# 2                   0.153763               0.001702 2020-03-31 21:41:29.221485
# 3                   0.003478              25.432904 2020-03-31 21:41:30.338186
# 4                  25.432904               0.003094 2020-03-31 21:41:31.468422
# ...                      ...                    ...                        ...
# 75640               0.007000               0.161324 2020-04-01 21:41:21.709038
# 75641               0.250000               0.161332 2020-04-01 21:41:22.862913
# 75642               0.161327               5.111623 2020-04-01 21:41:23.974732
# 75643               2.197566               0.158000 2020-04-01 21:41:25.106834
# 75644               0.300000               0.013749 2020-04-01 21:41:26.234630
#
# [75645 rows x 95 columns]

# %%
cross_val_score( LogisticRegression(n_jobs=-1, solver='lbfgs'), klines, y)
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# array([0.57258567, 0.53703011, 0.50965812])

# %%
y = get_state(klines, 0.003)

# %%
klines = klines[y != -1]
y = y[y != -1]

# %%
model, X_train, X_test, y_train, y_test, probas = fit(klines, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.52      0.42      5029
#            1       0.66      0.50      0.57      9416
#
#     accuracy                           0.51     14445
#    macro avg       0.51      0.51      0.50     14445
# weighted avg       0.56      0.51      0.52     14445

# %%
to_leave = [['depth_ask_price_' + str(i), 'depth_ask_quantity_' + str(i), 'depth_bid_price_' + str(i),
             'depth_bid_quantity_' + str(i)] for i in range(1, 21)]
lea = []
for el in to_leave:
    lea += el

# %%
klines.drop(lea, axis=1, inplace=True)
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
def get_importances(model):
    imp = model.feature_importances_
    names = model.get_booster().feature_names
    li = list(zip(imp, names))
    li.sort(reverse=True)
    return li

# %%
get_importances(model)[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-0af3a52f1b81> in <module>
# ----> 1 get_importances(model)[:10]
#
# <ipython-input-18-d6e22c5a0aa9> in get_importances(model)
#       1 def get_importances(model):
# ----> 2     imp = model.feature_importances_
#       3     names = model.get_booster().feature_names
#       4     li = list(zip(imp, names))
#       5     li.sort(reverse=True)
#
# AttributeError: 'LogisticRegression' object has no attribute 'feature_importances_'

# %%
def plot(X_test, y_test, probas):
    X_test1 = X_test[-3600:]
    probas1 = probas[-3600:]
    y_test1 = y_test[-3600:]
    
    X_test1['target'] = (X_test1['depth_bid_price_1'] + X_test1['depth_ask_price_1']) / 2.

    ups = probas1['maximum'] > 0.5
    downs = probas1['minimum'] > 0.5

    plt.figure(figsize=(15, 5))
    plt.plot(X_test1.index, X_test1['target'])
    plt.scatter(X_test1[y_test1 == 1].index, X_test1[y_test1== 1]['target'], color='g')
    plt.scatter(X_test1[y_test1 == 0].index, X_test1[y_test1 == 0]['target'], color='r')
    plt.show()
    plt.figure(figsize=(15, 5))
    plt.plot(X_test1.index, X_test1['target'])
    plt.scatter(X_test1[ups].index, X_test1[ups]['target'], color='r')
    plt.scatter(X_test1[downs].index, X_test1[downs]['target'], color='g')

# %%
plot(X_test, y_test, probas)
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data
# Out:
#              id          time currency_pair  depth_bid_price_1  \
# 38     19393420  1.585480e+09       btcusdt            6171.02
# 39     19393431  1.585480e+09       btcusdt            6169.35
# 40     19393442  1.585480e+09       btcusdt            6172.29
# 41     19393453  1.585480e+09       btcusdt            6171.43
# 42     19393464  1.585480e+09       btcusdt            6170.00
# ...         ...           ...           ...                ...
# 75385  20222245  1.585566e+09       btcusdt            6271.56
# 75386  20222256  1.585566e+09       btcusdt            6270.03
# 75387  20222267  1.585566e+09       btcusdt            6269.46
# 75388  20222278  1.585566e+09       btcusdt            6268.54
# 75389  20222289  1.585566e+09       btcusdt            6268.61
#
#        depth_bid_price_2  depth_bid_price_3  depth_bid_price_4  \
# 38               6169.66            6169.63            6169.35
# 39               6169.27            6169.26            6169.11
# 40               6171.37            6171.33            6171.15
# 41               6171.15            6171.09            6169.89
# 42               6169.90            6169.81            6169.72
# ...                  ...                ...                ...
# 75385            6271.45            6271.11            6270.66
# 75386            6270.02            6269.40            6269.37
# 75387            6269.45            6269.37            6269.00
# 75388            6268.50            6268.09            6268.06
# 75389            6268.60            6268.51            6268.50
#
#        depth_bid_price_5  depth_bid_price_6  depth_bid_price_7  ...  \
# 38               6169.26            6169.09            6168.86  ...
# 39               6169.10            6169.09            6168.86  ...
# 40               6171.09            6170.74            6170.71  ...
# 41               6169.74            6169.71            6169.29  ...
# 42               6168.86            6168.67            6168.66  ...
# ...                  ...                ...                ...  ...
# 75385            6270.65            6270.64            6270.55  ...
# 75386            6269.04            6269.00            6268.97  ...
# 75387            6268.37            6268.32            6268.31  ...
# 75388            6268.00            6267.51            6267.16  ...
# 75389            6268.04            6268.00            6267.51  ...
#
#        depth_ask_quantity_13  depth_ask_quantity_14  depth_ask_quantity_15  \
# 38                  0.243080               0.200000               0.039355
# 39                  0.300000               0.003000               0.543050
# 40                  0.200000               0.343570               0.323839
# 41                  0.009000               0.411216               0.309000
# 42                  0.162059               0.162032               0.009000
# ...                      ...                    ...                    ...
# 75385               0.119402               0.400000               0.400000
# 75386               0.500000               0.500043               0.500000
# 75387               0.300202               0.309066               0.309000
# 75388               0.500000               0.289838               0.200000
# 75389               0.200000               0.159515               0.104720
#
#        depth_ask_quantity_16  depth_ask_quantity_17  depth_ask_quantity_18  \
# 38                  0.300000               0.543078               0.543050
# 39                  6.200000               0.009000               0.108380
# 40                  0.019677               0.300000               1.385907
# 41                  0.102180               0.425698               0.162034
# 42                  0.300000               0.309000               0.102180
# ...                      ...                    ...                    ...
# 75385               0.300000               0.400000               0.159459
# 75386               0.368509               0.200000               0.008991
# 75387               3.000000               0.159527               0.008991
# 75388               0.309021               0.309000               1.000024
# 75389               0.289838               0.030000               0.309000
#
#        depth_ask_quantity_19  depth_ask_quantity_20  \
# 38                  6.200000               0.009000
# 39                  0.294000               0.093402
# 40                  0.300045               0.300000
# 41                  0.013626               0.250000
# 42                  0.013626               0.250000
# ...                      ...                    ...
# 75385               0.500000               0.069362
# 75386               0.159478               0.200000
# 75387               0.159478               0.239257
# 75388               0.644989               3.000000
# 75389               0.644989               3.000000
#
#                      normal_time  kline_id
# 38    2020-03-29 14:00:00.344851       1.0
# 39    2020-03-29 14:00:01.538996       1.0
# 40    2020-03-29 14:00:03.486393       1.0
# 41    2020-03-29 14:00:05.288622       1.0
# 42    2020-03-29 14:00:06.488622       1.0
# ...                          ...       ...
# 75385 2020-03-30 13:59:10.586653    1438.0
# 75386 2020-03-30 13:59:11.770475    1438.0
# 75387 2020-03-30 13:59:12.899944    1438.0
# 75388 2020-03-30 13:59:14.044932    1438.0
# 75389 2020-03-30 13:59:15.208242    1438.0
#
# [75352 rows x 85 columns]

# %%
reload(stonks.auxiliary.data_preprocessing)
reload(stonks.auxiliary.model_selection)
# Out:
# <module 'stonks.auxiliary.model_selection' from '../stonks/auxiliary/model_selection.py'>

# %%
data = count_some(data, 5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-0de947e057ca> in <module>
# ----> 1 data = count_some(data, 5)
#
# ~/programs/projects/Distonx/stonks/auxiliary/data_preprocessing.py in count_some(orders, depth)
#     158             continue
#     159         name = col.split('_')
# --> 160         orders['mid_distance_' + name[1] + '_' + name[3]] = orders[col] / orders['mid_price'] - 1.
#     161
#     162     # Cumulative notional value
#
# IndexError: list index out of range

# %%
from stonks.auxiliary.data_preprocessing import construct_order_names

# %%
orders = data[construct_order_names(5)]

# %%
some = count_some(orders, 5)
# Out:
# ../stonks/auxiliary/data_preprocessing.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['mid_price'] = (orders['depth_bid_price_1'] + orders['depth_ask_price_1']) / 2.
# ../stonks/auxiliary/data_preprocessing.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['mid_distance_' + name[1] + '_' + name[3]] = orders[col] / orders['mid_price'] - 1.
# ../stonks/auxiliary/data_preprocessing.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['cumulative_ask_1'] = orders['depth_ask_price_1'] * orders['depth_ask_quantity_1']
# ../stonks/auxiliary/data_preprocessing.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['cumulative_bid_1'] = orders['depth_bid_price_1'] * orders['depth_bid_quantity_1']
# ../stonks/auxiliary/data_preprocessing.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   'cumulative_ask_' + str(i - 1)]
# ../stonks/auxiliary/data_preprocessing.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   'cumulative_bid_' + str(i - 1)]
# ../stonks/auxiliary/data_preprocessing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (orders['cumulative_ask_' + str(i)] + orders['cumulative_bid_' + str(i)])
# ../stonks/auxiliary/data_preprocessing.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['spread'] = orders['depth_ask_price_1'] - orders['depth_bid_price_1']

# %%
some.drop(construct_order_names(5), axis=1, inplace=True)
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
some.drop('mid_price', axis=1, inplace=True)

# %%
from stonks.auxiliary.model_selection import fit_predict, plot_predictions

# %%
from stonks.auxiliary.data_preprocessing import get_state_cpp

# %%
y3 = get_state(data, 0.003)

# %%
y1 = get_state(data, 0.001)

# %%
model, x_train, x_test, y_train, y_test, probas = fit_predict(some, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.90      0.70      7971
#            1       0.49      0.12      0.20      6008
#
#     accuracy                           0.57     13979
#    macro avg       0.53      0.51      0.45     13979
# weighted avg       0.54      0.57      0.49     13979

# %%
plot_predictions(x_test[:3600], y_test[:3600], data.loc[y_test[:3600].index]['mid_price'], probas[:3600], prob_up=0.65, prob_down=0.65)

# %%
from sklearn.preprocessing import StandardScaler

def rolling(data: pd.Series):
    df = pd.DataFrame()
    periods = ['5s', '15s', '30s', '1min', '5min']
    for period in periods:
        df['rolling_' + period] = data / data.rolling(period).mean()
    return df

# %%
rollings = rolling(data['mid_price'])

# %%
rollings
# Out:
#                             rolling_5s  rolling_15s  rolling_30s  \
# normal_time
# 2020-03-31 21:41:26.934706    1.000000     1.000000     1.000000
# 2020-03-31 21:41:28.096272    1.000001     1.000001     1.000001
# 2020-03-31 21:41:29.221485    0.999967     0.999967     0.999967
# 2020-03-31 21:41:30.338186    1.000006     1.000006     1.000006
# 2020-03-31 21:41:31.468422    1.000015     1.000015     1.000015
# ...                                ...          ...          ...
# 2020-04-01 21:41:21.709038    1.000049     0.999857     0.999863
# 2020-04-01 21:41:22.862913    1.000050     0.999856     0.999880
# 2020-04-01 21:41:23.974732    0.999933     0.999788     0.999817
# 2020-04-01 21:41:25.106834    0.999928     0.999800     0.999800
# 2020-04-01 21:41:26.234630    0.999961     0.999856     0.999822
#
#                             rolling_1min  rolling_5min
# normal_time
# 2020-03-31 21:41:26.934706      1.000000      1.000000
# 2020-03-31 21:41:28.096272      1.000001      1.000001
# 2020-03-31 21:41:29.221485      0.999967      0.999967
# 2020-03-31 21:41:30.338186      1.000006      1.000006
# 2020-03-31 21:41:31.468422      1.000015      1.000015
# ...                                  ...           ...
# 2020-04-01 21:41:21.709038      0.999661      0.999183
# 2020-04-01 21:41:22.862913      0.999672      0.999184
# 2020-04-01 21:41:23.974732      0.999601      0.999102
# 2020-04-01 21:41:25.106834      0.999587      0.999076
# 2020-04-01 21:41:26.234630      0.999612      0.999091
#
# [75645 rows x 5 columns]

# %%
some = some.merge(rollings, on=some.index)

# %%
some.rename(columns={'key_0': 'normal_time'}, inplace=True)
some.set_index('normal_time', inplace=True)

# %%
some = pd.DataFrame(StandardScaler().fit_transform(some), index=some.index, columns=some.columns)

# %%
def plot_predictions(X_test, y_test, target, probas, prob_up=0.5, prob_down=0.5):
    """Отрисовывает предсказания модели"""

    ups = probas['goes_down'] > prob_down
    downs = probas['goes_up'] > prob_up

    plt.figure(figsize=(15, 5))
    plt.plot(X_test.index, target)
    plt.scatter(X_test[y_test == 1].index, target[y_test == 1], color='g')
    plt.scatter(X_test[y_test == 0].index, target[y_test == 0], color='r')
    plt.show()
    plt.figure(figsize=(15, 5))
    plt.plot(X_test.index, target)
    plt.scatter(X_test[ups].index, target[ups], color='r')
    plt.scatter(X_test[downs].index, target[downs], color='g')

# 2020-04-01 16:31:20.489327    -0.551604     -0.112222      0.006242
# ...                                 ...           ...           ...
# 2020-04-01 21:29:54.851430     0.201370      0.279998      0.993727
# 2020-04-01 21:29:55.960876     0.202454      0.293889      0.992660
# 2020-04-01 21:29:57.135619     0.203534      0.319990      0.997267
# 2020-04-01 21:29:58.300332     0.172925      0.317320      0.989657
# 2020-04-01 21:29:59.429237     0.130352      0.302168      0.976361
#
# [13979 rows x 31 columns]

# %%
import joblib

# %%
log = joblib.load('output.joblib')

# %%
log
# Out:
# [(1585817050.5435627,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7550579187551556, 0.24494208124484446)]),
#  (1585817051.5308201,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6491359295271264, 0.3508640704728736)]),
#  (1585817052.536766,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7465202654166259, 0.2534797345833741)]),
#  (1585817053.5549524,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.8983327369318364, 0.10166726306816364)]),
#  (1585817054.5172038,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7592697870882685, 0.24073021291173152)]),
#  (1585817055.581208,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6878471354867706, 0.3121528645132294)]),
#  (1585817056.5429509,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6794240292093158, 0.32057597079068423)]),
#  (1585817057.535758,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6693297332039189, 0.33067026679608114)]),
#  (1585817058.531271,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.5950598904169706, 0.4049401095830294)]),
#  (1585817059.5222108,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7487196902142121, 0.2512803097857879)]),
#  (1585817060.497362,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.706695395687275, 0.2933046043127249)]),
#  (1585817061.521953,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6880798981777105, 0.31192010182228946)]),
#  (1585817062.5339205,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7546788122821323, 0.24532118771786773)]),
#  (1585817063.5444417,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6437141107866351, 0.35628588921336496)]),
#  (1585817064.5697176,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6600603085780284, 0.33993969142197156)]),
#  (1585817065.5496826,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6106561075599177, 0.3893438924400822)]),
#  (1585817066.538449,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.614459911056763, 0.38554008894323694)]),
#  (1585817067.5337374,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6147764633078483, 0.38522353669215165)]),
#  (1585817068.5425801,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.587385135568451, 0.412614864431549)]),
#  (1585817069.5271382,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6158519944801666, 0.38414800551983347)]),
#  (1585817070.5140529,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.5675122653925004, 0.43248773460749956)]),
#  (1585817071.5303242,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.788972014751647, 0.211027985248353)]),
#  (1585817072.5336576,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.8190823837689065, 0.18091761623109343)]),
#  (1585817073.5264015,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7977725325791077, 0.20222746742089226)]),
#  (1585817074.5761795,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.8130556025132143, 0.18694439748678576)]),
#  (1585817075.5943642,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.8006338049721602, 0.19936619502783987)]),
#  (1585817076.5354764,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 200.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.7931865400100169, 0.20681345998998313)])]

# %% [markdown]
# # !!! #

# %%
from stonks.auxiliary.data_preprocessing import basic_clean, count_some
data = basic_clean(data)

# %%
y1 = get_state(data, 0.001)
y3 = get_state(data, 0.003)
y5 = get_state(data, 0.005)

plot_state(data, y3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-308a5edd036f> in <module>
#       1 y1 = get_state(data, 0.001)
#       2 y3 = get_state(data, 0.003)
# ----> 3 y5 = get_state(data, 0.005)
#       4
#       5 plot_state(data, y3)
#
# ~/programs/projects/Distonx/stonks/auxiliary/data_preprocessing.py in get_state(data, mod)
#      77             a = target[start:start + period].values
#      78
# ---> 79             diff_mat = a - a[:, None] * (1. + mod)
#      80             upper = (np.triu(diff_mat) > 0).argmax(1)
#      81             np.place(upper, upper == 0, 10 ** 9)
#
# KeyboardInterrupt:

# %%
y3
# Out:
# normal_time
# 2020-03-23 12:36:45.802038    1
# 2020-03-23 12:36:46.943040    1
# 2020-03-23 12:36:48.070125    1
# 2020-03-23 12:36:49.167385    1
# 2020-03-23 12:36:50.306284    1
#                              ..
# 2020-04-02 12:36:40.492260   -1
# 2020-04-02 12:36:41.627532   -1
# 2020-04-02 12:36:42.774224   -1
# 2020-04-02 12:36:43.899697   -1
# 2020-04-02 12:36:45.055389   -1
# Length: 754437, dtype: int64

# %%
from stonks.auxiliary.data_preprocessing import construct_order_names
orders = data[construct_order_names(5)]
some = count_some(orders, 5)
some.drop(construct_order_names(5), axis=1, inplace=True)
some.drop('mid_price', axis=1, inplace=True)
#  scaler = StandardScaler()
#  scaler.fit(some)
#  some = pd.DataFrame(scaler.transform(some), index=some.index, columns=some.columns)
# Out:
# ../stonks/auxiliary/data_preprocessing.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['mid_price'] = (orders['depth_bid_price_1'] + orders['depth_ask_price_1']) / 2.
# ../stonks/auxiliary/data_preprocessing.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['mid_distance_' + name[1] + '_' + name[3]] = orders[col] / orders['mid_price'] - 1.
# ../stonks/auxiliary/data_preprocessing.py:174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['cumulative_ask_1'] = orders['depth_ask_price_1'] * orders['depth_ask_quantity_1']
# ../stonks/auxiliary/data_preprocessing.py:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['cumulative_bid_1'] = orders['depth_bid_price_1'] * orders['depth_bid_quantity_1']
# ../stonks/auxiliary/data_preprocessing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   'cumulative_ask_' + str(i - 1)]
# ../stonks/auxiliary/data_preprocessing.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   'cumulative_bid_' + str(i - 1)]
# ../stonks/auxiliary/data_preprocessing.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (orders['cumulative_ask_' + str(i)] + orders['cumulative_bid_' + str(i)])
# ../stonks/auxiliary/data_preprocessing.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders['spread'] = orders['depth_ask_price_1'] - orders['depth_bid_price_1']
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data['mid_price'] = (data['depth_bid_price_1'] + data['depth_ask_price_1']) / 2.

# %%
rols = rolling(data.loc[some.index]['mid_price'])

# %%
df = pd.concat([some, rols], axis=1)

# %%
df = pd.DataFrame(StandardScaler().fit_transform(df), columns=df.columns, index=df.index)

# %%
from stonks.auxiliary.model_selection import fit_predict, plot_predictions

# %%
model, x_train, x_test, y_train, y_test, probas = fit_predict(df, y1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.42      0.48     76543
#            1       0.52      0.63      0.57     74251
#
#     accuracy                           0.53    150794
#    macro avg       0.53      0.53      0.52    150794
# weighted avg       0.53      0.53      0.52    150794

# %%
pd.Series(model.predict(x_test)).value_counts()
# Out:
# 1    90884
# 0    59910
# dtype: int64

# %%
plot_predictions(x_test[:3600], y_test[:3600], data.loc[y_test.index]['mid_price'][:3600], probas[:3600], prob_up=0.53, prob_down=0.53)

# %%
logs = joblib.load('output.joblib')

# %%
logs
# Out:
# [(1585817237.3663032,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.5877725083233545, 0.4122274916766456)]),
#  (1585817238.3149917,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.583926082104326, 0.41607391789567405)]),
#  (1585817239.3197591,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.5860080894992585, 0.4139919105007414)]),
#  (1585817240.333551,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.5814327035723705, 0.41856729642762946)]),
#  (1585817241.3187273,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6075366289224544, 0.3924633710775456)]),
#  (1585817242.3150864,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.5863596678803533, 0.41364033211964674)]),
#  (1585817243.3445702,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.6271473765168556, 0.37285262348314435)]),
#  (1585817244.3390017,
#   [('btcusdt', 'sell base', 0.0)],
#   {'usdt': 0.0, 'btc': 0.0, 'ltc': 0.0, 'eth': 0.0, 'bch': 0.0, 'bnb': 0.0},
#   {'usdt': 199.91999801999995,
#    'btc': 9.999999999975306e-07,
#    'ltc': 0.0,
#    'eth': 0.0,
#    'bch': 0.0,
#    'bnb': 0.0},
#   200.0,
#   0.0,
#   [('btcusdt', 0.